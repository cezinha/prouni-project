# %%
import pandas as pd

# %%
df = pd.read_csv("cursos-prouni.csv")

# %%
df.head()
# Out:
#   uf_busca     cidade_busca  \
# 0       AC       Acrelandia
# 1       AC  Cruzeiro do Sul
# 2       AC  Cruzeiro do Sul
# 3       AC  Cruzeiro do Sul
# 4       AC       Rio Branco
#
#                                    universidade_nome  \
# 0                       Universidade Paulista - UNIP
# 1  Centro Universitário Internacional - Uninter -...
# 2               Faculdade Educacional da Lapa - FAEL
# 3                       Universidade Paulista - UNIP
# 4  Centro Universitário Internacional - Uninter -...
#
#                                 campus_nome           nome         grau  \
# 0                       ACRELANDIA - Centro  Administração  Bacharelado
# 1              PAP CRUZEIRO DO SUL - Centro  Administração  Bacharelado
# 2  AC - CRUZEIRO DO SUL - POLO EAD - CENTRO  Administração  Bacharelado
# 3                  CRUZEIRO DO SUL - Centro  Administração  Bacharelado
# 4                   PAP RIO BRANCO - Bosque  Administração  Bacharelado
#
# ...

# %%
for i, v in enumerate(df.columns):
    print(i, v)
# Out:
# 0 uf_busca
# 1 cidade_busca
# 2 universidade_nome
# 3 campus_nome
# 4 nome
# 5 grau
# 6 turno
# 7 mensalidade
# 8 bolsa_integral_cotas
# 9 bolsa_integral_ampla
# 10 bolsa_parcial_cotas
# 11 bolsa_parcial_ampla
# 12 nota_integral_ampla
# 13 nota_integral_cotas
# 14 nota_parcial_ampla
# 15 nota_parcial_cotas

# %%
df[df.nome == "Administração"].describe()
# Out:
#        mensalidade  bolsa_integral_cotas  bolsa_integral_ampla  \
# count  2754.000000           2288.000000           1799.000000
# mean    542.997491              1.774038              2.876598
# std     392.767032              2.473487              4.184736
# min     169.000000              0.000000              1.000000
# 25%     298.000000              1.000000              1.000000
# 50%     393.675000              1.000000              2.000000
# 75%     694.772500              2.000000              3.000000
# max    6552.520000             37.000000             67.000000
#
#        bolsa_parcial_cotas  bolsa_parcial_ampla  nota_integral_ampla  \
# count           570.000000           867.000000          2288.000000
# mean              2.096491            11.916955           575.236670
# std               2.020846            25.640435            42.079418
# min               1.000000             1.000000           450.000000
# ...

# %%
df[df.nome == "Administração"].groupby("uf_busca").describe()
# Out:
#          bolsa_integral_ampla                                                 \
#                         count      mean       std  min  25%  50%   75%   max
# uf_busca
# AC                        5.0  1.200000  0.447214  1.0  1.0  1.0  1.00   2.0
# AL                       15.0  1.866667  1.187234  1.0  1.0  1.0  2.50   5.0
# AM                       13.0  1.692308  1.931520  1.0  1.0  1.0  1.00   8.0
# AP                        6.0  1.833333  0.983192  1.0  1.0  1.5  2.75   3.0
# BA                       65.0  2.153846  3.083377  1.0  1.0  1.0  2.00  16.0
# CE                       45.0  1.600000  1.498484  1.0  1.0  1.0  2.00  10.0
# DF                       30.0  1.933333  1.529781  1.0  1.0  1.0  2.00   6.0
# ES                       32.0  2.156250  1.461536  1.0  1.0  2.0  3.00   6.0
# GO                       57.0  2.122807  1.881016  1.0  1.0  1.0  3.00  10.0
# MA                       21.0  1.857143  2.080522  1.0  1.0  1.0  1.00  10.0
# ...
