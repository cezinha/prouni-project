# %%
import pandas as pd

# %% [markdown]
# Lendo os dados do CSV

# %%
df = pd.read_csv("cursos-prouni.csv")

# %%
df.head()
# Out:
#   uf_busca     cidade_busca  \
# 0       AC       Acrelandia
# 1       AC  Cruzeiro do Sul
# 2       AC  Cruzeiro do Sul
# 3       AC  Cruzeiro do Sul
# 4       AC       Rio Branco
#
#                                    universidade_nome  \
# 0                       Universidade Paulista - UNIP
# 1  Centro Universitário Internacional - Uninter -...
# 2               Faculdade Educacional da Lapa - FAEL
# 3                       Universidade Paulista - UNIP
# 4  Centro Universitário Internacional - Uninter -...
#
#                                 campus_nome           nome         grau  \
# 0                       ACRELANDIA - Centro  Administração  Bacharelado
# 1              PAP CRUZEIRO DO SUL - Centro  Administração  Bacharelado
# 2  AC - CRUZEIRO DO SUL - POLO EAD - CENTRO  Administração  Bacharelado
# 3                  CRUZEIRO DO SUL - Centro  Administração  Bacharelado
# 4                   PAP RIO BRANCO - Bosque  Administração  Bacharelado
#
# ...

# %%
for i, v in enumerate(df.columns):
    print(i, v)
# Out:
# 0 uf_busca
# 1 cidade_busca
# 2 universidade_nome
# 3 campus_nome
# 4 nome
# 5 grau
# 6 turno
# 7 mensalidade
# 8 bolsa_integral_cotas
# 9 bolsa_integral_ampla
# 10 bolsa_parcial_cotas
# 11 bolsa_parcial_ampla
# 12 nota_integral_ampla
# 13 nota_integral_cotas
# 14 nota_parcial_ampla
# 15 nota_parcial_cotas

# %%
df[df.nome == "Administração"]['mensalidade'].describe()
# Out:
# count    2754.000000
# mean      542.997491
# std       392.767032
# min       169.000000
# 25%       298.000000
# 50%       393.675000
# 75%       694.772500
# max      6552.520000
# Name: mensalidade, dtype: float64

# %%
df[df.nome == "Administração"].groupby("uf_busca")['mensalidade'].describe()
# Out:
#           count        mean         std    min       25%      50%        75%  \
# uf_busca
# AC         12.0  422.846667  177.606954  250.0  298.0000  325.000   487.6975
# AL         19.0  442.887368  169.488933  169.0  298.0000  417.140   586.6300
# AM         24.0  516.304167  222.672974  219.0  321.0000  566.660   687.9675
# AP         12.0  484.623333  255.563701  229.0  298.0000  384.065   654.0375
# BA        194.0  477.486856  249.348830  189.0  295.0000  327.325   660.2300
# CE         74.0  604.299054  284.284166  229.0  406.2725  522.520   715.0000
# DF         64.0  615.235938  282.211430  175.0  321.0000  688.910   812.0150
# ES         69.0  496.647536  267.745255  199.0  298.0000  402.650   699.0000
# GO         99.0  458.153434  218.915882  169.0  299.0000  390.000   577.1400
# MA         49.0  522.502857  207.559136  229.0  309.0000  514.710   760.0300
# MG        294.0  606.520578  330.694369  209.0  319.0000  534.020   859.9375
# ...

# %%
df[(df.nome == "Ciência da Computação") | (df.nome == "Ciências da Computação")]['mensalidade'].describe()
# Out:
# count     216.000000
# mean      926.433009
# std       431.367237
# min       309.500000
# 25%       637.612500
# 50%       799.350000
# 75%      1167.612500
# max      4023.000000
# Name: mensalidade, dtype: float64

# %%
df[(df.nome == "Ciência da Computação") | (df.nome == "Ciências da Computação")].groupby("uf_busca")['mensalidade'].describe()
# Out:
#           count         mean          std     min        25%       50%  \
# uf_busca
# AL          3.0   711.926667   109.246218  585.78   680.3900   775.000
# AM          4.0   795.600000   134.071241  611.88   737.7600   837.560
# AP          3.0   653.360000    33.283461  618.00   638.0000   658.000
# BA          3.0   687.933333   280.931723  474.27   528.8250   583.380
# CE          4.0   761.975000   288.763676  476.98   589.8550   710.960
# DF          7.0   991.835714   190.717430  755.45   855.3700   907.050
# ES          4.0   735.625000   245.673579  512.26   532.4950   718.620
# GO          6.0   951.918333   354.321142  603.93   736.1950   793.895
# MG         13.0   995.413846   188.129554  714.72   858.3600   978.000
# MS          3.0   606.296667   192.420615  482.74   495.4450   508.150
# MT          1.0   858.000000          NaN  858.00   858.0000   858.000
# PA          3.0   987.630000   557.990167  647.22   665.6500   684.080
# ...

# %%
# %matplotlib notebook

df[(df.nome == "Ciência da Computação") | (df.nome == "Ciências da Computação")]['mensalidade'].hist()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib

matplotlib.style.use('ggplot')
df[(df.nome == "Ciência da Computação") | (df.nome == "Ciências da Computação")].boxplot(column="mensalidade")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib

matplotlib.style.use('ggplot')
df[(df.nome == "Ciência da Computação") | (df.nome == "Ciências da Computação")].boxplot(column="mensalidade", by="uf_busca")
# Out:
# <img src="data:image/png;base64,..." width="640">
